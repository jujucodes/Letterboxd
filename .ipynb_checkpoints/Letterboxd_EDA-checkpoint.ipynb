# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df = pd.read_csv('data/Horror.csv')
df.head()
# Out:
#              title    year         director  running_time   views   likes  \
# 0          Get Out  2017.0     Jordan Peele           104  605132  261668
# 1       Zombieland  2009.0  Ruben Fleischer            88  339357   77110
# 2         Suspiria  2018.0  Luca Guadagnino           152  122728   37820
# 3        Halloween  1978.0   John Carpenter            91  212751   59124
# 4  Rosemary's Baby  1968.0   Roman Polanski           137  158689   46272
#
#    avg_rating  half_star  one_star  one_half_star  two_star  two_half_star  \
# 0         4.1        647      1560           1001      5727           5821
# 1         3.6        477      1384           1353      6280           9055
# 2         3.7        611      1253           1266      4151           4844
# 3         4.0        204       700            602      3003           3627
# 4         4.2        156       372            253      1326           1412
#
#    three_star  three_half_star  four_star  four_half_star  five_star
# ...

# %%
df.describe(include='all')
# Out:
#                title          year        director  running_time  \
# count          11052  11046.000000           10976  11052.000000
# unique         10339           NaN            6826           NaN
# top     Frankenstein           NaN  David DeCoteau           NaN
# freq               8           NaN              48           NaN
# mean             NaN   1997.829712             NaN     83.197883
# std              NaN     20.641835             NaN     28.903248
# min              NaN   1895.000000             NaN      1.000000
# 25%              NaN   1986.000000             NaN     80.000000
# 50%              NaN   2006.000000             NaN     89.000000
# 75%              NaN   2014.000000             NaN     95.000000
# max              NaN   2020.000000             NaN    608.000000
#
#                 views          likes    avg_rating     half_star  \
# count    11052.000000   11052.000000  11052.000000  11052.000000
# ...

# %%
df.info()
# maybe convert object to string? does it matter?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11052 entries, 0 to 11051
# Data columns (total 17 columns):
# title              11052 non-null object
# year               11046 non-null float64
# director           10976 non-null object
# running_time       11052 non-null int64
# views              11052 non-null int64
# likes              11052 non-null int64
# avg_rating         11052 non-null float64
# half_star          11052 non-null int64
# one_star           11052 non-null int64
# one_half_star      11052 non-null int64
# two_star           11052 non-null int64
# two_half_star      11052 non-null int64
# three_star         11052 non-null int64
# three_half_star    11052 non-null int64
# four_star          11052 non-null int64
# four_half_star     11052 non-null int64
# five_star          11052 non-null int64
# dtypes: float64(2), int64(13), object(2)
# memory usage: 1.4+ MB

# %%
df.isna().sum()
# Out:
# title               0
# year                6
# director           76
# running_time        0
# views               0
# likes               0
# avg_rating          0
# half_star           0
# one_star            0
# one_half_star       0
# two_star            0
# two_half_star       0
# three_star          0
# three_half_star     0
# four_star           0
# four_half_star      0
# five_star           0
# dtype: int64

# %%
df['title'][df['director'].isna()]
# Out:
# 1064                                      Harper's Island
# 1274                             Todd McFarlane's Spawn 2
# 1457                                    Silent Hills P.T.
# 1638                                          Prai Takian
# 1731                                    Tokyo Ghoul: Jack
# 1752                    Boogeymen: The Killer Compilation
# 1910                                                 Büyü
# 2029                                  Traces of Death III
# 2178             Trailer Trauma Part 4: Television Trauma
# 2217                                    Night Night Nancy
# 2224                                      No Through Road
# 2227                      Traces of Death IV: Resurrected
# 2232                                           After Dark
# 2235                              The Ticket of Leave Man
# 2247                                     Killer Christmas
# 2384                                        Antoni Psycho
# ...

# %%
df['title'][df['year'].isna()]
# Out:
# 2400                                      President's Day
# 2448    The Very Best of Ghost Hunters: Vol. 1: Most B...
# 2454                                        Silent Breath
# 2506                            The Golden Arm (Michigan)
# 2638                                                 Shed
# 2664                                Frozen 2: Even Better
# Name: title, dtype: object

# %%
df['avg_rating'].mean()
# Out:
# 2.8100615273253724

# %%
# check that there's nothing unusual in the distribution of ratings
plt.plot(df['avg_rating'])
plt.show()

# %%
# drop null values
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10972 entries, 0 to 11051
# Data columns (total 17 columns):
# title              10972 non-null object
# year               10972 non-null float64
# director           10972 non-null object
# running_time       10972 non-null int64
# views              10972 non-null int64
# likes              10972 non-null int64
# avg_rating         10972 non-null float64
# half_star          10972 non-null int64
# one_star           10972 non-null int64
# one_half_star      10972 non-null int64
# two_star           10972 non-null int64
# two_half_star      10972 non-null int64
# three_star         10972 non-null int64
# three_half_star    10972 non-null int64
# four_star          10972 non-null int64
# four_half_star     10972 non-null int64
# five_star          10972 non-null int64
# dtypes: float64(2), int64(13), object(2)
# memory usage: 1.5+ MB

# %%
# drop columns with where either director or year is missing
# drop columns with non unique titles but check first whether the other features are different (different films with same title)
#maybe unique movies aren't important
df['title'].nunique()
# Out:
# 10264

# %%
features = ['year']
#upper case variables are dataframes
X = df[features]
#lowercase is a series
X.head()
# Out:
#      year
# 0  2017.0
# 1  2009.0
# 2  2018.0
# 3  1978.0
# 4  1968.0

# %%
# target vriable
target = ['avg_rating']
y = df[target]
y.head()
# Out:
#    avg_rating
# 0         4.1
# 1         3.6
# 2         3.7
# 3         4.0
# 4         4.2

# %%
model = LinearRegression()
model.fit(X, y)
model.coef_
# Out:
# array([[-0.00582086]])

# %%
model.score(X, y)
# Out:
# 0.06819965640280112

# %%
X
# Out:
#          year
# 0      2017.0
# 1      2009.0
# 2      2018.0
# 3      1978.0
# 4      1968.0
# 5      2011.0
# 6      2016.0
# 7      1982.0
# 8      2004.0
# 9      2014.0
# 10     1983.0
# 11     2020.0
# 12     2016.0
# 13     2014.0
# 14     2014.0
# 15     2019.0
# 16     1968.0
# 17     2015.0
# 18     1987.0
# 19     2004.0
# 20     2008.0
# 21     2019.0
# 22     1984.0
# 23     2018.0
# 24     1986.0
# 25     2017.0
# 26     1963.0
# 27     1975.0
# 28     2006.0
# 29     1931.0
# ...       ...
# 11022  2019.0
# 11023  1974.0
# 11024  2016.0
# 11025  1976.0
# 11026  2018.0
# 11027  1977.0
# 11028  2018.0
# 11029  1996.0
# 11030  2016.0
# 11031  1977.0
# 11032  2013.0
# 11033  2017.0
# 11034  2016.0
# 11035  2015.0
# 11036  2018.0
# 11037  1972.0
# 11038  2000.0
# 11039  1960.0
# 11040  2017.0
# 11041  1979.0
# 11042  2015.0
# 11043  2018.0
# 11044  1975.0
# 11045  2010.0
# 11046  1991.0
# 11047  2019.0
# 11048  2018.0
# 11049  1980.0
# 11050  2019.0
# 11051  2019.0
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-ffcb6358e8f6> in <module>
# ----> 1 X = X.drop('x_pred')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
ax = plt.scatter(X, y)

plt.show()

# %%
ax

# %%
X

# %%
y_pred = model.predict(X)
plt.scatter(X, y)
plt.scatter(X, y_pred)
plt.show()

# %%
#compare both on the same scatter plot
df_y = y.copy()
#new dataframe with new column
df_y['y_pred'] = y_pred
# plt.scatter(X, df_y)
df_y.head()

# %%
X['x_pred'] = X['year']
plt.scatter(X, df_y)
yaxis =

# %%
features = []

# %%
length of directors names
use git dummies to train a model

# %%
letterboxd_eda

# %%
# what did I learn from this first model
# knowing what I know what's important to stakeholders - why is this trend happening

# calculate length of directors name and lenght of the titel of the movie
# converts them to numerical values, train new model on the x (directors) and y(rating)
#length is informative

# %%
# genre feature training

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import numpy as np
pd.options.display.max_columns = 10000

# %%
#read in new df from preprocessing
df = pd.read_csv('df.csv', index_col=0)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (2,3,4,19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    Unnamed: 0.1            title        year         director  running_time  \
# 0           0.0          Get Out  2017-01-01     Jordan Peele         104.0
# 1           1.0       Zombieland  2009-01-01  Ruben Fleischer          88.0
# 2           2.0         Suspiria  2018-01-01  Luca Guadagnino         152.0
# 3           3.0        Halloween  1978-01-01   John Carpenter          91.0
# 4           4.0  Rosemary's Baby  1968-01-01   Roman Polanski         137.0
#
#       views     likes  avg_rating  half_star  one_star  one_half_star  \
# 0  605132.0  261668.0         4.1      647.0    1560.0         1001.0
# 1  339357.0   77110.0         3.6      477.0    1384.0         1353.0
# 2  122728.0   37820.0         3.7      611.0    1253.0         1266.0
# 3  212751.0   59124.0         4.0      204.0     700.0          602.0
# 4  158689.0   46272.0         4.2      156.0     372.0          253.0
#
#    two_star  two_half_star  three_star  three_half_star  four_star  \
# 0    5727.0         5821.0     34069.0          45053.0   136842.0
# 1    6280.0         9055.0     37228.0          43168.0    53117.0
# 2    4151.0         4844.0     12282.0          15033.0    25865.0
# 3    3003.0         3627.0     15715.0          17598.0    35627.0
# 4    1326.0         1412.0      6933.0           9562.0    27455.0
#
#    four_half_star  five_star   genre year_isna  animation  horror  scifi  \
# 0         65726.0   110264.0  horror     False        NaN     NaN    NaN
# 1         10931.0    11907.0  horror     False        NaN     NaN    NaN
# 2         13732.0    12889.0  horror     False        NaN     NaN    NaN
# 3         14882.0    29077.0  horror     False        NaN     NaN    NaN
# 4         18616.0    24435.0  horror     False        NaN     NaN    NaN
#
#    thriller  war
# 0       NaN  NaN
# 1       NaN  NaN
# 2       NaN  NaN
# 3       NaN  NaN
# 4       NaN  NaN

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0.1         title        year    director  running_time  \
# count   40018.000000         40018       40018       40018  40018.000000
# unique           NaN         30378         130       16293           NaN
# top              NaN  Frankenstein  2017-01-01  directorNA           NaN
# freq             NaN            18        1798         382           NaN
# mean     4892.286471           NaN         NaN         NaN     80.726548
# std      3334.753389           NaN         NaN         NaN     42.044645
# min         0.000000           NaN         NaN         NaN      1.000000
# 25%      2000.250000           NaN         NaN         NaN     73.000000
# 50%      4457.000000           NaN         NaN         NaN     90.000000
# 75%      7335.000000           NaN         NaN         NaN    100.000000
# max     12835.000000           NaN         NaN         NaN    897.000000
#
#                 views          likes    avg_rating     half_star  \
# count    40018.000000   40018.000000  40018.000000  40018.000000
# unique            NaN            NaN           NaN           NaN
# top               NaN            NaN           NaN           NaN
# freq              NaN            NaN           NaN           NaN
# mean      6826.995702    1316.224424      2.972707     54.423484
# std      34009.245241    9260.254979      0.473895    329.131089
# min         33.000000       0.000000      0.900000      0.000000
# 25%        109.250000      11.000000      2.700000      1.000000
# 50%        288.000000      34.000000      3.000000      4.000000
# 75%       1271.000000     165.000000      3.300000     16.000000
# max     719791.000000  286934.000000      4.600000  26627.000000
#
#             one_star  one_half_star      two_star  two_half_star  \
# count   40018.000000   40018.000000  40018.000000   40018.000000
# unique           NaN            NaN           NaN            NaN
# top              NaN            NaN           NaN            NaN
# freq             NaN            NaN           NaN            NaN
# mean      111.778300     105.667125    293.829577     309.652281
# std       570.423667     474.780097   1275.813010    1253.326690
# min         0.000000       0.000000      0.000000       0.000000
# 25%         2.000000       3.000000      8.000000       8.000000
# 50%         8.000000       9.000000     20.000000      21.000000
# 75%        31.000000      33.000000     82.000000      90.000000
# max     41716.000000   25062.000000  49076.000000   32039.000000
#
#           three_star  three_half_star      four_star  four_half_star  \
# count   40018.000000     40018.000000   40018.000000    40018.000000
# unique           NaN              NaN            NaN             NaN
# top              NaN              NaN            NaN             NaN
# freq             NaN              NaN            NaN             NaN
# mean      720.899595       614.732420     820.867235      299.167150
# std      3208.731177      2979.839044    5347.700701     2518.510737
# min         0.000000         0.000000       0.000000        0.000000
# 25%        13.000000         7.000000       4.000000        1.000000
# 50%        36.000000        22.000000      15.000000        3.000000
# 75%       172.000000       113.000000      87.000000       18.000000
# max     71584.000000     63621.000000  136870.000000    90025.000000
#
#             five_star     genre year_isna     animation        horror  \
# count    40018.000000     40018     40018  40018.000000  40018.000000
# unique            NaN         5         2           NaN           NaN
# top               NaN  thriller     False           NaN           NaN
# freq              NaN     12836     39998           NaN           NaN
# mean       403.334599       NaN       NaN      0.202984      0.276176
# std       4304.396370       NaN       NaN      0.402225      0.447110
# min          0.000000       NaN       NaN      0.000000      0.000000
# 25%          1.000000       NaN       NaN      0.000000      0.000000
# 50%          4.000000       NaN       NaN      0.000000      0.000000
# 75%         22.000000       NaN       NaN      0.000000      1.000000
# max     243931.000000       NaN       NaN      1.000000      1.000000
#
#                scifi      thriller           war
# count   40018.000000  40018.000000  40018.000000
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# mean        0.145609      0.320756      0.054475
# std         0.352719      0.466773      0.226956
# min         0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      0.000000
# 50%         0.000000      0.000000      0.000000
# 75%         0.000000      1.000000      0.000000
# max         1.000000      1.000000      1.000000

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1       40018
# title              40018
# year               40018
# director           40018
# running_time       40018
# views              40018
# likes              40018
# avg_rating         40018
# half_star          40018
# one_star           40018
# one_half_star      40018
# two_star           40018
# two_half_star      40018
# three_star         40018
# three_half_star    40018
# four_star          40018
# four_half_star     40018
# five_star          40018
# genre              40018
# year_isna          40018
# animation          40018
# horror             40018
# scifi              40018
# thriller           40018
# war                40018
# dtype: int64

# %%
# genre feature model training

# %%
model = LinearRegression()

# %%
X = df['likes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'likes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-b18f4f2d0ff3> in <module>
# ----> 1 X = df['likes']
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'likes'

# %%
y = df_genres['avg_rating']

# %%
X_train_true, X_test_true, y_train_true, y_test_true = train_test_split(X, y, test_size = 0.3, random_state=42)

# %%
model.fit(X_train_true, y_train_true)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_test_pred = model.predict(X_test_true)

# %%
model.score(X_test_true, y_test_true)
# Out:
# 0.1145999775841765

# %%
# predictive power for this feature
model.coef_
# Out:
# array([1.74025528e+11, 1.74025528e+11, 1.74025528e+11, 1.74025528e+11,
#        1.74025528e+11])

# %%
pd.Series(y_test_pred).unique()
# Out:
# array([2.93945312, 2.81246948, 2.90005493, 3.2215271 , 3.27639771])

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, y_test_pred))
rmse
# Out:
# 0.4487173642695912

# %%
y_error = y_test_pred - y_test_true
y_error
# Out:
# 6070     0.439453
# 5811    -0.160547
# 2299     0.312469
# 8671    -0.087531
# 12409   -0.760547
#            ...
# 5468    -0.378473
# 6280     0.212469
# 5953    -0.587531
# 5795    -0.099945
# 8192    -0.060547
# Name: avg_rating, Length: 12006, dtype: float64

# %%
standard_error = ((y_error**2).mean())**0.5
standard_error
# Out:
# 0.44871736426958847

# %%
plt.plot(X_test_true, model.predict(X_test_true), color='red',linewidth=3)
plt.show()
